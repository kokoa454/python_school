# %%
import pandas as pd
import statsmodels.formula.api as smf

data = pd.read_csv("practice.csv")
data.head()
# Out:
#    Tweets  Blog  Sales
# 0     228    46      4
# 1      87    21      5
# 2     492   127     11
# 3      58    12      6
# 4      43    30      2

# %%
data.corr()
# Out:
#           Tweets      Blog     Sales
# Tweets  1.000000  0.569534  0.780701
# Blog    0.569534  1.000000  0.507265
# Sales   0.780701  0.507265  1.000000

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, figsize = (10, 10), alpha = 0.5)
# Out:
# array([[<Axes: xlabel='Tweets', ylabel='Tweets'>,
#         <Axes: xlabel='Blog', ylabel='Tweets'>,
#         <Axes: xlabel='Sales', ylabel='Tweets'>],
#        [<Axes: xlabel='Tweets', ylabel='Blog'>,
#         <Axes: xlabel='Blog', ylabel='Blog'>,
#         <Axes: xlabel='Sales', ylabel='Blog'>],
#        [<Axes: xlabel='Tweets', ylabel='Sales'>,
#         <Axes: xlabel='Blog', ylabel='Sales'>,
#         <Axes: xlabel='Sales', ylabel='Sales'>]], dtype=object)

# %%
results = smf.ols("Sales ~ Tweets + Blog", data = data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     26.39
# Date:                Mon, 10 Nov 2025   Prob (F-statistic):           1.43e-07
# Time:                        12:31:27   Log-Likelihood:                -83.056
# No. Observations:                  36   AIC:                             172.1
# Df Residuals:                      33   BIC:                             176.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.2771      0.743      5.760      0.000       2.766       5.788
# Tweets         0.0121      0.002      5.541      0.000       0.008       0.017
# Blog           0.0063      0.009      0.706      0.485      -0.012       0.024
# ==============================================================================
# Omnibus:                        0.580   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.748   Jarque-Bera (JB):                0.662
# Skew:                           0.098   Prob(JB):                        0.718
# Kurtosis:                       2.365   Cond. No.                         693.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
