# %%
import pandas as pd
import statsmodels.formula.api as smf
from pandas.plotting import scatter_matrix

data = pd.read_csv("practice.csv")
data.head()
# Out:
#         日付,  つぶやき(ビッグデータ),  アクセス数(ビッグデータ),  つぶやき(データベース),  アクセス数(データベース),  \
# 0  2011/4/1           1292            1540           1509            1613
# 1  2011/4/2           1320            1399            417            1310
# 2  2011/4/3           1394            1281            113             943
# 3  2011/4/4           1399            1338            378            1093
# 4  2011/4/5           1270            1396            991            1304
#
#    アクセス平均年齢,  売上
# 0         48  70
# 1         49  69
# 2         39  74
# 3         44  73
# 4         41  69

# %%
data.columns = ['Date', 'Tweets_Bigdata', 'Access_Bigdata', 'Tweets_Database', 'Access_Database', 'Age', 'Sales']
data.corr(numeric_only = True)
# Out:
#                  Tweets_Bigdata  Access_Bigdata  Tweets_Database  \
# Tweets_Bigdata         1.000000        0.487788        -0.000504
# Access_Bigdata         0.487788        1.000000         0.403718
# Tweets_Database       -0.000504        0.403718         1.000000
# Access_Database        0.018361        0.733612         0.574563
# Age                   -0.519237       -0.463758         0.047352
# Sales                  0.697879        0.672507        -0.031471
#
#                  Access_Database       Age     Sales
# Tweets_Bigdata          0.018361 -0.519237  0.697879
# Access_Bigdata          0.733612 -0.463758  0.672507
# Tweets_Database         0.574563  0.047352 -0.031471
# Access_Database         1.000000  0.041875 -0.009579
# Age                     0.041875  1.000000 -0.728052
# Sales                  -0.009579 -0.728052  1.000000

# %%
scatter_matrix(data, figsize = (10, 10), alpha = 0.5)
# Out:
# array([[<Axes: xlabel='Tweets_Bigdata', ylabel='Tweets_Bigdata'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Tweets_Bigdata'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Tweets_Bigdata'>,
#         <Axes: xlabel='Access_Database', ylabel='Tweets_Bigdata'>,
#         <Axes: xlabel='Age', ylabel='Tweets_Bigdata'>,
#         <Axes: xlabel='Sales', ylabel='Tweets_Bigdata'>],
#        [<Axes: xlabel='Tweets_Bigdata', ylabel='Access_Bigdata'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Access_Bigdata'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Access_Bigdata'>,
#         <Axes: xlabel='Access_Database', ylabel='Access_Bigdata'>,
#         <Axes: xlabel='Age', ylabel='Access_Bigdata'>,
#         <Axes: xlabel='Sales', ylabel='Access_Bigdata'>],
#        [<Axes: xlabel='Tweets_Bigdata', ylabel='Tweets_Database'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Tweets_Database'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Tweets_Database'>,
#         <Axes: xlabel='Access_Database', ylabel='Tweets_Database'>,
#         <Axes: xlabel='Age', ylabel='Tweets_Database'>,
#         <Axes: xlabel='Sales', ylabel='Tweets_Database'>],
#        [<Axes: xlabel='Tweets_Bigdata', ylabel='Access_Database'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Access_Database'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Access_Database'>,
#         <Axes: xlabel='Access_Database', ylabel='Access_Database'>,
#         <Axes: xlabel='Age', ylabel='Access_Database'>,
#         <Axes: xlabel='Sales', ylabel='Access_Database'>],
#        [<Axes: xlabel='Tweets_Bigdata', ylabel='Age'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Age'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Age'>,
#         <Axes: xlabel='Access_Database', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Sales', ylabel='Age'>],
#        [<Axes: xlabel='Tweets_Bigdata', ylabel='Sales'>,
#         <Axes: xlabel='Access_Bigdata', ylabel='Sales'>,
#         <Axes: xlabel='Tweets_Database', ylabel='Sales'>,
#         <Axes: xlabel='Access_Database', ylabel='Sales'>,
#         <Axes: xlabel='Age', ylabel='Sales'>,
#         <Axes: xlabel='Sales', ylabel='Sales'>]], dtype=object)

# %%
results = smf.ols('Sales ~ Tweets_Bigdata + Access_Bigdata + Tweets_Database + Access_Database + Age', data = data).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.704e+06
# Date:                Thu, 13 Nov 2025   Prob (F-statistic):               0.00
# Time:                        14:18:17   Log-Likelihood:                 688.30
# No. Observations:                 366   AIC:                            -1365.
# Df Residuals:                     360   BIC:                            -1341.
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -27.3386      0.045   -604.594      0.000     -27.428     -27.250
# Tweets_Bigdata   1.815e-05   1.79e-05      1.015      0.311    -1.7e-05    5.33e-05
# Access_Bigdata      0.1168   3.28e-05   3563.779      0.000       0.117       0.117
# Tweets_Database  1.147e-05   7.34e-06      1.564      0.119   -2.96e-06    2.59e-05
# Access_Database    -0.0512   1.72e-05  -2972.963      0.000      -0.051      -0.051
# Age                -0.0002      0.001     -0.452      0.652      -0.001       0.001
# ==============================================================================
# Omnibus:                       50.199   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               13.227
# Skew:                          -0.026   Prob(JB):                      0.00134
# Kurtosis:                       2.070   Cond. No.                     5.54e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print("売上 = (-27.3386) + 0.1168 * アクセス数(ビッグデータ) + (-0.0512) * アクセス数(データベース)")
